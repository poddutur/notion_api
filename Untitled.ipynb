# %%
token_id = "857e45a167aa91fc5041166d3ffb2c24534126ec0a6b56cf95d27985d31a22dd3bdb30d1c15d5a2966eaff3ca013236649ca05eabd9274b231e84c840265cb2ec46df9afc3122f7de00c1dd82b3f"
page_id = "https://www.notion.so/test-7eee18b489d34d75a8178b05ed14e700"

# %%
from notion.client import NotionClient
client = NotionClient(token_v2=token_id)
page = client.get_block(page_id)
print("The old title is:", page.title)
# Out:
# The old title is: test

# %%
from notion.block import TodoBlock

newchild = page.children.add_new(TodoBlock, title="Something to get done")
newchild.checked = False

# %%
from notion.block import VideoBlock

video = page.children.add_new(VideoBlock, width=200)
video.set_source_url("https://www.youtube.com/watch?v=oHg5SJYRHA0")

# %%
from notion.block import VideoBlock

video = page.children.add_new(VideoBlock, width=800)
video.set_source_url("https://www.youtube.com/watch?v=oHg5SJYRHA0")

# %%
from notion.block import VideoBlock

video = page.children.add_new(VideoBlock, width=200, height=500)
video.set_source_url("https://www.youtube.com/watch?v=oHg5SJYRHA0")

# %%
cv = client.get_collection_view("https://www.notion.so/7ed7fe0fdc7246898312dcf59a6822cd?v=c37272b63dba4b1c8b16db2f977439a4")

for row in cv.collection.get_rows(search=""):
    print("We estimate the value of '{}' at {}".format(row.Name, row.Type))

# Add a new record
row = cv.collection.add_row()
row.Name = "Just some data"
row.Type = 'immersive show'

# Run a filtered/sorted query using a view's default parameters
result = cv.default_query().execute()
for row in result:
    print(row)

# # Run an "aggregation" query
# aggregate_params = [{
#     "property": "estimated_value",
#     "aggregation_type": "sum",
#     "id": "total_value",
# }]
# result = cv.build_query(aggregate=aggregate_params).execute()
# print("Total estimated value:", result.get_aggregate("total_value"))

# # Run a "filtered" query
# filter_params = [{
#     "property": "assigned_to",
#     "comparator": "enum_contains",
#     "value": client.current_user,
# }]
# result = cv.build_query(filter=filter_params).execute()
# print("Things assigned to me:", result)

# # Run a "sorted" query
# sort_params = [{
#     "direction": "descending",
#     "property": "estimated_value",
# }]
# result = cv.build_query(sort=sort_params).execute()
# print("Sorted results, showing most valuable first:", result)
# Out:
# We estimate the value of 'Beat the Bomb' at ['Excape Room']
# We estimate the value of 'Brain Xcape' at ['Excape Room']
# We estimate the value of 'Zero Space' at ['Immersive Show']
# We estimate the value of 'Sleep No More' at ['Immersive Show']
# We estimate the value of 'Archery' at ['Archery']
# We estimate the value of 'Axe Throwing' at ['Axe Throwing']
# We estimate the value of 'VR World' at ['VR Experience']
# We estimate the value of 'Vessel ' at ['Monument']
# We estimate the value of 'House of Showfields' at ['Museum']
# We estimate the value of 'Spy Space' at ['Museum']
# We estimate the value of 'National Museum of Mathematics' at ['Museum']
# We estimate the value of 'Just some data' at []
# id='d6909ae4-3213-441d-94ce-bee0002bfc0c', title='Beat the Bomb'
# id='9f610c3a-36bd-4c13-a2c5-5b08f0f2eac3', title='Brain Xcape'
# id='f8582401-3f0f-47ab-9c57-241cdee51f96', title='Zero Space'
# id='88a88efd-aaca-464a-9a50-70154dbad9e4', title='Sleep No More'
# ...

# %%
filter_params = [{
    "property": "title",
    "comparator": "contains",
    "value": "VR",
}]
result = cv.build_query(filter=filter_params).execute()
print("Things assigned to me:", result)
# Out:
# Things assigned to me: [
#   <CollectionRowBlock (id='d6909ae4-3213-441d-94ce-bee0002bfc0c', title='Beat the Bomb')>,
#   <CollectionRowBlock (id='9f610c3a-36bd-4c13-a2c5-5b08f0f2eac3', title='Brain Xcape')>,
#   <CollectionRowBlock (id='f8582401-3f0f-47ab-9c57-241cdee51f96', title='Zero Space')>,
#   <CollectionRowBlock (id='88a88efd-aaca-464a-9a50-70154dbad9e4', title='Sleep No More')>,
#   <CollectionRowBlock (id='db986079-fd4e-470e-9bf0-c1607977250e', title='Archery')>,
#   <CollectionRowBlock (id='f6a00722-5cdb-46d7-8f88-25f9186e4d1e', title='Axe Throwing')>,
#   <CollectionRowBlock (id='b2f9a4bb-6f0d-4dda-941f-771d86da06a6', title='VR World')>,
#   <CollectionRowBlock (id='5f96b89b-5bf0-49ff-b757-92e6e333d6ec', title='Vessel ')>,
#   <CollectionRowBlock (id='144c2ea9-1ea0-464d-840b-4fb372dc9ad3', title='House of Showfields')>,
#   <CollectionRowBlock (id='91f262b0-00e9-4b85-80ae-9a53c28cd3f1', title='Spy Space')>,
# ...

# %%
result = cv.default_query().execute()
for row in result:
    if row.title == 'Beat the Bomb':
        row.price = 104

# %%
block = client.get_block("https://www.notion.so/test-7eee18b489d34d75a8178b05ed14e700#b3258708452342c8aa64c712c79d4dd9")
block
# Out:
# <ImageBlock (id='b3258708-4523-42c8-aa64-c712c79d4dd9', source='https://s3.us-west-2.amazonaws.com/secure.notion-static.com/4046400f-cdbb-4ff0-b9d1-7e78288a75a7/statue-of-liberty.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAT73L2G45FB4AXXV3%2F20200121%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20200121T151744Z&X-Amz-Expires=86400&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIHDDFgikB3xjvB9i8Of%2BBUGoervvCGbIdeegWfSMiOR0AiALiGkxXTIsZrPZNfIPdD1eMG41XECqNfGjK0VeSz00sCq0AwgSEAAaDDI3NDU2NzE0OTM3MCIMEJd55cQIL5l9Mg14KpEDfWST7RuLmr3svElbXrYnrB4NxKGdAGsPiD0GPWKbEhapXHs7CqoezuyVcNt1Fr2VYTS%2FMTuK4vajNA5B4hwVev4Kf1V9biI7aBNi%2BSNO6tpT6Ldkwh4uQE2g3M2LK9yjga%2FM1%2FiqgWubrpGF9Nqo5r6aXKude45yN6%2B5IBHPnrB0XDWq3rGmk1K5TbekGpuF%2FbCkysl8svquJ9pFl%2F%2FqLON3p3d%2BuMAfvX%2Bx9aWwAUPHVCO8BLCuyOKjbk%2Bs1F6XLZB2OhEnf206IZuOvHbK59VHoJAXEYE%2BpCvfO6cm%2FLNqVk7ZiLOalD6AGlPynj%2BwYwRt8ls9LUYCSHW0i6vL1ZpUUTL9n6Jup%2BzXW7%2FKsp0dCTJ00Cjygmv1VN%2BjtUaGJUYbWp9i4NBsdrCEpWHEQjQ3hWXCCVuU
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3],[1,1,5])
plt.savefig("test.png")
plt.show()

# %%
block.set_source_url("/home/spoddutur/personal_projects/notion_api/test.png")

# %%
# %%bash
# pwd
# Out:
# /home/spoddutur/personal_projects/notion_api
